# %% [markdown]
# # Zillow Data Analysis
# This notebook loads and joins three Zillow datasets using DuckDB.

# %%
import duckdb
import pandas as pd
from pathlib import Path

# Set pandas display options to show more data
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

# %% [markdown]
# ## Load Data into DuckDB

# %%
# Connect to DuckDB
conn = duckdb.connect()

# Define base path using pathlib for Windows compatibility
# Notebook is in src/exploratory/, so go up 1 level to src/, then into raw_datasets/
raw_data_path = Path("../raw_datasets").resolve()

# Define CSV file paths
csv_paths = [
  raw_data_path / "ZILLOW_DATA_962c837a6ccefddddf190101e0bafdaf.csv",
  raw_data_path / "ZILLOW_INDICATORS_e93833a53d6c88463446a364cda611cc.csv",
  raw_data_path / "ZILLOW_REGIONS_1a51d107db038a83ac171d604cb48d5b.csv"
]

names = [
  "ZILLOW_DATA",
  "ZILLOW_INDICATORS",
  "ZILLOW_REGIONS"
]

# Drop tables if they exist
for name in names:
  conn.execute(f"DROP TABLE IF EXISTS {name}")

# Create tables from CSV files
for i, csv_path in enumerate(csv_paths):
  # Convert Path to string and use forward slashes for DuckDB
  csv_str = str(csv_path).replace('\\', '/')
  conn.execute(f"CREATE TABLE {names[i]} AS SELECT * FROM read_csv_auto('{csv_str}')")
  print(f"✓ Loaded {names[i]}")
# Out:
# ✓ Loaded ZILLOW_DATA
# ✓ Loaded ZILLOW_INDICATORS
# ✓ Loaded ZILLOW_REGIONS

# %% [markdown]
# ## Explore Individual Tables

# %%
# Check ZILLOW_DATA
print("ZILLOW_DATA - First 5 rows:")
zillow_data = conn.execute("SELECT * FROM ZILLOW_DATA LIMIT 5").fetchdf()
display(zillow_data)
print(f"\nShape: {conn.execute('SELECT COUNT(*) FROM ZILLOW_DATA').fetchone()[0]} rows")
# Out:
# ZILLOW_DATA - First 5 rows:
#   indicator_id  region_id       date     value
# 0         ZATT       3101 1998-01-31  338849.0
# 1         ZATT       3101 1998-02-28  342993.0
# 2         ZATT       3101 1998-03-31  346763.0
# 3         ZATT       3101 1998-04-30  349356.0
# 4         ZATT       3101 1998-05-31  351981.0
# Shape: 159663189 rows

# %%
# Check ZILLOW_INDICATORS
print("ZILLOW_INDICATORS - First 5 rows:")
zillow_indicators = conn.execute("SELECT * FROM ZILLOW_INDICATORS LIMIT 5").fetchdf()
display(zillow_indicators)
print(f"\nShape: {conn.execute('SELECT COUNT(*) FROM ZILLOW_INDICATORS').fetchone()[0]} rows")
# Out:
# ZILLOW_INDICATORS - First 5 rows:
#   indicator_id                                          indicator  \
# 0         SAAW  Median Sale Price (Smooth & Seasonally Adjuste...
# 1         SRAM        Median Sale Price (Raw, All Homes, Monthly)
# 2         NSAM  Median Days to Pending (Smooth, All Homes, Mon...
# 3         RSNA  ZORI (Smoothed): All Homes Plus Multifamily Ti...
# 4         RSSA  ZORI (Smoothed, Seasonally Adjusted): All Home...
#
#               category
# 0  Inventory and sales
# 1  Inventory and sales
# 2  Inventory and sales
# 3              Rentals
# 4              Rentals
# Shape: 56 rows

# %%
# Check ZILLOW_REGIONS
print("ZILLOW_REGIONS - First 5 rows:")
zillow_regions = conn.execute("SELECT * FROM ZILLOW_REGIONS LIMIT 5").fetchdf()
display(zillow_regions)
print(f"\nShape: {conn.execute('SELECT COUNT(*) FROM ZILLOW_REGIONS').fetchone()[0]} rows")
# Out:
# ZILLOW_REGIONS - First 5 rows:
#    region_id region_type                                             region
# 0      96208         zip  90706;CA;Los Angeles-Long Beach-Anaheim, CA;Be...
# 1     394415       metro                                     Bridgeport, CT
# 2     394653       metro                                     Greenville, SC
# 3     394312       metro                                    Albuquerque, NM
# 4     394357       metro                                    Bakersfield, CA
# Shape: 89305 rows

# %% [markdown]
# ## Join All Three Tables

# %%
# Join the three tables
query = """
SELECT *
FROM ZILLOW_DATA d
JOIN ZILLOW_INDICATORS i ON d.indicator_id = i.indicator_id
JOIN ZILLOW_REGIONS r ON d.region_id = r.region_id
LIMIT 10
"""

result = conn.execute(query).fetchdf()
print(f"Joined Data: {result.shape[0]} rows × {result.shape[1]} columns")
display(result)
# Out:
# Joined Data: 10 rows × 10 columns
#   indicator_id  region_id       date     value indicator_id_1  \
# 0         ZATT       3101 1998-01-31  338849.0           ZATT
# 1         ZATT       3101 1998-02-28  342993.0           ZATT
# 2         ZATT       3101 1998-03-31  346763.0           ZATT
# 3         ZATT       3101 1998-04-30  349356.0           ZATT
# 4         ZATT       3101 1998-05-31  351981.0           ZATT
# 5         ZATT       3101 1998-06-30  354231.0           ZATT
# 6         ZATT       3101 1998-07-31  355713.0           ZATT
# 7         ZATT       3101 1998-08-31  357529.0           ZATT
# 8         ZATT       3101 1998-09-30  360523.0           ZATT
# 9         ZATT       3101 1998-10-31  363858.0           ZATT
#
#                                   indicator     category  region_id_1  \
# 0  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 1  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 2  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 3  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 4  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 5  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 6  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 7  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 8  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
# 9  ZHVI All Homes- Top Tier Time Series ($)  Home values         3101
#
#   region_type                                             region
# 0      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 1      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 2      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 3      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 4      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 5      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 6      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 7      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 8      county  Los Angeles County;CA;Los Angeles-Long Beach-A...
# 9      county  Los Angeles County;CA;Los Angeles-Long Beach-A...

# %% [markdown]
# ## View All Columns

# %%
# List all column names
print("All columns in joined data:")
for i, col in enumerate(result.columns, 1):
    print(f"{i:2d}. {col}")
# Out:
# All columns in joined data:
#  1. indicator_id
#  2. region_id
#  3. date
#  4. value
#  5. indicator_id_1
#  6. indicator
#  7. category
#  8. region_id_1
#  9. region_type
# 10. region

# %% [markdown]
# ## Get More Rows

# %%
# Get more rows if needed
query_more = """
SELECT *
FROM ZILLOW_DATA d
JOIN ZILLOW_INDICATORS i ON d.indicator_id = i.indicator_id
JOIN ZILLOW_REGIONS r ON d.region_id = r.region_id
WHERE i.indicator_id = 'CRAW' AND 
d.region_id = '102001' AND
d.date = '2018-01-13'
"""

result_more = conn.execute(query_more).fetchdf()
print(f"Extended Data: {result_more.shape[0]} rows × {result_more.shape[1]} columns")
display(result_more)
# Out:
# Extended Data: 1 rows × 10 columns
#   indicator_id  region_id       date     value indicator_id_1  \
# 0         CRAW     102001 2018-01-13  0.048289           CRAW
#
#                                            indicator             category  \
# 0  Share of Listings With a Price Cut (Raw, All H...  Inventory and sales
#
#    region_id_1 region_type         region
# 0       102001       metro  United States

# %% [markdown]
# ## Data Info

# %%
# Get info about the dataframe
print("DataFrame Info:")
result_more.info()

print("\n" + "="*80)
print("\nBasic Statistics:")
display(result_more.describe())
# Out:
# DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   indicator_id    10 non-null     object
#  1   region_id       10 non-null     int64
#  2   date            10 non-null     datetime64[us]
#  3   value           10 non-null     float64
#  4   indicator_id_1  10 non-null     object
#  5   indicator       10 non-null     object
#  6   category        10 non-null     object
#  7   region_id_1     10 non-null     int64
#  8   region_type     10 non-null     object
#  9   region          10 non-null     object
# dtypes: datetime64[us](1), float64(1), int64(2), object(6)
# memory usage: 932.0+ bytes
#
# ================================================================================
#
# Basic Statistics:
#            region_id                 date      value    region_id_1
# count      10.000000                   10  10.000000      10.000000
# mean   394881.300000  2020-08-22 16:48:00  11.800000  394881.300000
# min    394521.000000  2020-08-15 00:00:00   5.000000  394521.000000
# 25%    394849.000000  2020-08-16 18:00:00   5.000000  394849.000000
# 50%    394862.000000  2020-08-22 00:00:00   6.000000  394862.000000
# 75%    395005.250000  2020-08-29 00:00:00  16.000000  395005.250000
# max    395053.000000  2020-08-29 00:00:00  33.000000  395053.000000
# std       157.235174                  NaN  10.591401     157.235174

# %% [markdown]
# ## Region Types

# %%
# Ajustar display para não cortar o texto
pd.set_option('display.max_colwidth', None)

# Consultar todos os tipos de região (region_type)
query_region_types = """
SELECT 
    region_type
FROM ZILLOW_REGIONS
GROUP BY region_type
"""

region_types = conn.execute(query_region_types).fetchdf()
print("Types of Regions Available:")
display(region_types)

# Mostrar exemplos de cada tipo
print("\n" + "="*80)
print("Examples of Each Region Type:")
print("="*80)
for rt in region_types['region_type']:
    print(f"\n{rt}:")
    examples = conn.execute(f"""
        SELECT region_id, region_type, region
        FROM ZILLOW_REGIONS 
        WHERE region_type = '{rt}'
        LIMIT 3
    """).fetchdf()
    display(examples)
# Out:
# Types of Regions Available:
#   region_type
# 0        city
# 1         zip
# 2      county
# 3       metro
# 4       state
# 5       neigh
# ================================================================================
# Examples of Each Region Type:
# ================================================================================
#
# city:
#    region_id region_type  \
# 0      32503        city
# 1      17384        city
# 2      13437        city
#
#                                                               region
# 0                            Lincoln;NE;Lincoln, NE;Lancaster County
# 1              Chandler;AZ;Phoenix-Mesa-Chandler, AZ;Maricopa County
# 2  Randolph Township; NJ; New York-Newark-Jersey City; Morris County
# zip:
#    region_id region_type  \
# 0      96208         zip
# 1      95315         zip
# 2      91325         zip
#
#                                                                       region
# 0  90706;CA;Los Angeles-Long Beach-Anaheim, CA;Bellflower;Los Angeles County
# 1                     87121;NM;Albuquerque, NM;Albuquerque;Bernalillo County
# 2         76244;TX;Dallas-Fort Worth-Arlington, TX;Fort Worth;Tarrant County
# county:
#    region_id region_type  \
# 0       2841      county
# 1       1286      county
# 2        445      county
#
#                                                    region
# 0  San Diego County;CA;San Diego-Chula Vista-Carlsbad, CA
# 1     Orange County;CA;Los Angeles-Long Beach-Anaheim, CA
# 2        Clark County;NV;Las Vegas-Henderson-Paradise, NV
# metro:
#    region_id region_type           region
# 0     394415       metro   Bridgeport, CT
# 1     394653       metro   Greenville, SC
# 2     394312       metro  Albuquerque, NM
# state:
#    region_id region_type       region
# 0          9       state   California
# 1         11       state  Connecticut
# 2         55       state         Utah
# neigh:
#    region_id region_type  \
# 0     274772       neigh
# 1     273698       neigh
# 2     275473       neigh
#
#                                                                          region
# 0  Northeast Dallas; TX; Dallas-Fort Worth-Arlington, TX; Dallas County; Dallas
# 1         Far North; TX; Dallas-Fort Worth-Arlington, TX; Dallas County; Dallas
# 2  Southeast Dallas; TX; Dallas-Fort Worth-Arlington, TX; Dallas County; Dallas

# %%
## Indicators Analysis

# %%
# Contar quantos indicadores existem
total_indicators = conn.execute("SELECT COUNT(*) FROM ZILLOW_INDICATORS").fetchone()[0]
print(f"Total de Indicadores: {total_indicators}")

# Mostrar 5 exemplos de indicadores
print("\n" + "="*80)
print("5 Exemplos de Indicadores:")
print("="*80)
examples = conn.execute("""
    SELECT 
        indicator_id,
        indicator,
        category,
    FROM ZILLOW_INDICATORS 
    LIMIT 5
""").fetchdf()
display(examples)
# Out:
# Total de Indicadores: 56
#
# ================================================================================
# 5 Exemplos de Indicadores:
# ================================================================================
#   indicator_id  \
# 0         SAAW
# 1         SRAM
# 2         NSAM
# 3         RSNA
# 4         RSSA
#
#                                                                           indicator  \
# 0          Median Sale Price (Smooth & Seasonally Adjusted, All Homes, Weekly View)
# 1                                       Median Sale Price (Raw, All Homes, Monthly)
# 2                               Median Days to Pending (Smooth, All Homes, Monthly)
# 3                       ZORI (Smoothed): All Homes Plus Multifamily Time Series ($)
# 4  ZORI (Smoothed, Seasonally Adjusted): All Homes Plus Multifamily Time Series ($)
#
#               category
# 0  Inventory and sales
# 1  Inventory and sales
# 2  Inventory and sales
# 3              Rentals
# 4              Rentals
